# %%
import pandas as pd

# %%
# Basic example of DataFrame

info={
    "Name":["Ayush","Dishant","Goldy","Sanket","Vikas"],
    "CGPA":[9.5,7.5,8.5,6.5,9.9],
}

dataFrame=pd.DataFrame(info)

# Here Pandas will automatically structure the data 

print(dataFrame)        # Not in a good looking tabular form
dataFrame               # In a good looking tabular form
# Out:
#       Name  CGPA
# 0    Ayush   9.5
# 1  Dishant   7.5
# 2    Goldy   8.5
# 3   Sanket   6.5
# 4    Vikas   9.9
#       Name  CGPA
# 0    Ayush   9.5
# 1  Dishant   7.5
# 2    Goldy   8.5
# 3   Sanket   6.5
# 4    Vikas   9.9
