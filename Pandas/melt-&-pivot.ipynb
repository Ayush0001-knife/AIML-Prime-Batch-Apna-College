# %%
import pandas as pd

# %%
# Melt ->  To convert data from wide format to long format

# Wide format data
df=pd.DataFrame({
    "country":["USA","USA","India","India"],
    "year":[2020,2021,2020,2021],
    "sales":[100,120,90,110],
    "profit":[20,25,18,22],
    "tax":[10,20,30,40]
})

# Long Format Data
melted_df=df.melt(
    id_vars=["country","year"],             # We want to keep these columns  
    value_vars=["sales","profit","tax"],    # These two columns will be melted into one single column third column
    var_name="metrics",                     # This will be the name of the third column
    value_name="value"                      # This will create the fourth column where the values for the third column will be stored
)

# %%
df
# Out:
#   country  year  sales  profit  tax
# 0     USA  2020    100      20   10
# 1     USA  2021    120      25   20
# 2   India  2020     90      18   30
# 3   India  2021    110      22   40
