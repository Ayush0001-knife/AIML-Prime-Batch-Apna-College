# %%
import json

# %%
# Access or Load the Data

def load_data(filename):
    with open (filename,"r") as f:
        data=json.load(f)

    return data

data=load_data("sample_product_rating_data.json")

# %%
# Clean The Data

def clean_data(data):

    text_to_num = {"one":1,"two":2,"three":3,"four":4,"five":5,}
    cleaned_data=[]
    unique_users=set()
    
    for user in data:
        # Clean the rating because it has mixed data type.
        if "rating" in user:
            # Clean string
            rating = str(user["rating"]).strip().lower()
            
            # Convert text → number
            if rating in text_to_num:
                rating = text_to_num[rating]

            user["rating"]=rating    

        # Handling missing value.
        raw_age = user.get("age")
        if raw_age is None:
            user["age"] = None

        # Handling Duplicate Data.
        # Deduplication 

        if(user["name"].strip() in unique_users):
            continue
        else:
            unique_users.add(user["name"].strip())
            cleaned_data.append(user)

    return cleaned_data

# %%
cleanData=clean_data(data)
print(cleanData)
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'Great product!!', 'age': '25'}, {'name': 'Bob', 'rating': '4', 'feedback': 'ok but late Delivery', 'age': '30'}, {'name': 'Charlie', 'rating': '2', 'feedback': 'BAD EXPERIENCE', 'age': None}, {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'}, {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - could be better', 'age': '20'}]

# %%
# Get Meaningful Insights like avg-rating and % of users gave poor rating

def get_insights(data):

    # Average Rating
    total_rating = 0
    
    for user in data:
        total_rating += float(user["rating"])
        
    avg_rating = total_rating/len(data)
    print(f"Average Rating : {avg_rating}")


    # Percentage of users with Poor rating
    poor_ratings=0
    for user in data:
        if(float(user["rating"]) < 3.0 ):
            poor_ratings+=1

    total_percentage = (poor_ratings/len(data))*100
    print(f"Percentage of users with poor Rating : {total_percentage}%")

# %%
get_insights(cleanData)
# Out:
# Average Rating : 3.9
# Percentage of users with poor Rating : 20.0
