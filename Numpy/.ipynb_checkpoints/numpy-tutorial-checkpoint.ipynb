# %%
import numpy as np

# %%
# This is the simple python list

arr=[1,2,3,4,5]
print(arr)
# Out:
# [1, 2, 3, 4, 5]

# %%
# This is the numpy array

new_arr=np.array([1,2,3,4,5])
print(new_arr)
# Out:
# [1 2 3 4 5]
